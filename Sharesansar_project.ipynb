# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.sharesansar.com/live-trading','html.parser')
soup = requests.get(url)
soup.text

soup = BeautifulSoup(soup.text,'lxml')
soup
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=no, initial-scale = 1.0, minimum-scale=1.0, maximum-scale = 1.0" name="viewport"/>
# ...

# %%
css_soup = BeautifulSoup('<div class="floatThead-wrapper"></div>','xml')
css_soup.p['class']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 css_soup = BeautifulSoup('<div class="floatThead-wrapper"></div>','xml')
# ----> 2 css_soup.p['class']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#tags = table_code.find_all("div", class_="floatThead-wrapper")
#tags
